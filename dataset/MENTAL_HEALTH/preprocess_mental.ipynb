# %%
import pandas as pd
import numpy as np
import glob

# %%
df = pd.read_csv('estat_hlth_cd_aro.csv')
df.columns = df.columns.str.strip()
df = df.apply(lambda x: x.str.strip() if x.dtype == "object" else x)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11610 entries, 0 to 11609
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   freq    11610 non-null  object
#  1   unit    11610 non-null  object
#  2   sex     11610 non-null  object
#  3   age     11610 non-null  object
#  4   icd10   11610 non-null  object
#  5   resid   11610 non-null  object
#  6   geo     11610 non-null  object
#  7   2016    11610 non-null  object
#  8   2017    11610 non-null  object
#  9   2018    11610 non-null  object
#  10  2019    11610 non-null  object
#  11  2020    11610 non-null  object
#  12  2021    11610 non-null  object
#  13  2022    11610 non-null  object
#  14  2023    11610 non-null  object
# dtypes: object(15)
# memory usage: 1.3+ MB

# %%
path = '../../ESTAT_CODELISTS/*.tsv'
files = glob.glob(path)
dataframes = {file.split('/')[-1].replace('.tsv', ''): pd.read_csv(
    file, sep='\t') for file in files}

# %%
for col in ["freq", "unit", "sex", "age", "icd10", "resid", "geo"]:
    curr_codelist = dataframes[f"ESTAT_{col.upper()}"]
    df[col] = df[col].map(curr_codelist.set_index('CODE')['Label'])

df.rename(columns={'geo': 'country'}, inplace=True)
df.head()
# Out:
#      freq    unit      sex    age                                       icd10  \
# 0  Annual  Number  Females  Total  Mental and behavioural disorders (F00-F99)
# 1  Annual  Number  Females  Total  Mental and behavioural disorders (F00-F99)
# 2  Annual  Number  Females  Total  Mental and behavioural disorders (F00-F99)
# 3  Annual  Number  Females  Total  Mental and behavioural disorders (F00-F99)
# 4  Annual  Number  Females  Total  Mental and behavioural disorders (F00-F99)
#
#                                 resid      country  2016  2017  2018  2019  \
# 0  All deaths reported in the country      Austria  1164  1830  2011  1980
# 1  All deaths reported in the country      Belgium  3334  3544  3493  3679
# 2  All deaths reported in the country     Bulgaria    40    33    35    40
# 3  All deaths reported in the country  Switzerland  3347  3781  3798  3856
# 4  All deaths reported in the country       Cyprus   108   117   164   179
#
#    2020  2021  2022  2023
# 0  1850  2047  2242  2444
# 1  3527  2984  3461     :
# 2    57    51    39     :
# 3  3789  3452  3978     :
# 4   155   194   221     :

# %%
df.replace(": z", np.nan, inplace=True)
df.replace(":", np.nan, inplace=True)

# %%
year_cols = [col for col in df.columns if col.isdigit()]

for col in year_cols:
    df[col] = df[col].astype(str).str.extract(r'(\d+)').astype(float)

# %%
df.head()
# Out:
#      freq    unit      sex    age                                       icd10  \
# 0  Annual  Number  Females  Total  Mental and behavioural disorders (F00-F99)
# 1  Annual  Number  Females  Total  Mental and behavioural disorders (F00-F99)
# 2  Annual  Number  Females  Total  Mental and behavioural disorders (F00-F99)
# 3  Annual  Number  Females  Total  Mental and behavioural disorders (F00-F99)
# 4  Annual  Number  Females  Total  Mental and behavioural disorders (F00-F99)
#
#                                 resid      country    2016    2017    2018  \
# 0  All deaths reported in the country      Austria  1164.0  1830.0  2011.0
# 1  All deaths reported in the country      Belgium  3334.0  3544.0  3493.0
# 2  All deaths reported in the country     Bulgaria    40.0    33.0    35.0
# 3  All deaths reported in the country  Switzerland  3347.0  3781.0  3798.0
# 4  All deaths reported in the country       Cyprus   108.0   117.0   164.0
#
#      2019    2020    2021    2022    2023
# 0  1980.0  1850.0  2047.0  2242.0  2444.0
# 1  3679.0  3527.0  2984.0  3461.0     NaN
# 2    40.0    57.0    51.0    39.0     NaN
# 3  3856.0  3789.0  3452.0  3978.0     NaN
# 4   179.0   155.0   194.0   221.0     NaN

# %%
for col in df.columns:
    if not col.isdigit() and df[col].nunique() == 1:
        df.drop(columns=[col], inplace=True)

# %%
df.head()
# Out:
#        sex    age                                       icd10  \
# 0  Females  Total  Mental and behavioural disorders (F00-F99)
# 1  Females  Total  Mental and behavioural disorders (F00-F99)
# 2  Females  Total  Mental and behavioural disorders (F00-F99)
# 3  Females  Total  Mental and behavioural disorders (F00-F99)
# 4  Females  Total  Mental and behavioural disorders (F00-F99)
#
#                                 resid      country    2016    2017    2018  \
# 0  All deaths reported in the country      Austria  1164.0  1830.0  2011.0
# 1  All deaths reported in the country      Belgium  3334.0  3544.0  3493.0
# 2  All deaths reported in the country     Bulgaria    40.0    33.0    35.0
# 3  All deaths reported in the country  Switzerland  3347.0  3781.0  3798.0
# 4  All deaths reported in the country       Cyprus   108.0   117.0   164.0
#
#      2019    2020    2021    2022    2023
# 0  1980.0  1850.0  2047.0  2242.0  2444.0
# 1  3679.0  3527.0  2984.0  3461.0     NaN
# 2    40.0    57.0    51.0    39.0     NaN
# 3  3856.0  3789.0  3452.0  3978.0     NaN
# 4   179.0   155.0   194.0   221.0     NaN

# %%
# df.to_csv("./clean/estat_hlth_cd_aro.csv", index=False)

# %%
df = pd.read_csv('./clean/estat_hlth_cd_aro.csv')

covid_conditions = ['COVID-19, virus identified', 'COVID-19, virus not identified', 'COVID-19, other']
covid_df = df[df['icd10'].isin(covid_conditions)].groupby(['sex', 'age', 'resid', 'country']).sum().reset_index()
covid_df['icd10'] = 'COVID-19'

# Drop the original rows and append the new aggregated row
df = df[~df['icd10'].isin(covid_conditions)]
df = pd.concat([df, covid_df], ignore_index=True)
df.icd10.unique()
# Out:
# array(['Mental and behavioural disorders due to use of alcohol', 'Total',
#        'Drug dependence, toxicomania (F11-F16, F18-F19)',
#        'Intentional self-harm', 'COVID-19',
#        'Mental and behavioural disorders'], dtype=object)

# %%
mental = ['Mental and behavioural disorders (F00-F99)', 'Other mental and behavioural disorders (remainder of F00-F99)']
mental_df = df[df['icd10'].isin(mental)].groupby(['sex', 'age', 'resid', 'country']).sum().reset_index()
mental_df['icd10'] = 'Mental and behavioural disorders'

# Drop the original rows and append the new aggregated row
df = df[~df['icd10'].isin(mental)]
df = pd.concat([df, mental_df], ignore_index=True)
df.icd10.unique()
# Out:
# array(['Mental and behavioural disorders due to use of alcohol', 'Total',
#        'Drug dependence, toxicomania (F11-F16, F18-F19)',
#        'Intentional self-harm', 'COVID-19',
#        'Mental and behavioural disorders'], dtype=object)

# %%
df = df.rename(columns={'icd10': 'cause'})
df['cause'] = df['cause'].replace('Drug dependence, toxicomania (F11-F16, F18-F19)', 'Drug dependence')
df['cause'] = df['cause'].replace('Mental and behavioural disorders due to use of alcohol', 'Use of alcohol')


df.head()
# Out:
#        sex    age           cause                               resid  \
# 0  Females  Total  Use of alcohol  All deaths reported in the country
# 1  Females  Total  Use of alcohol  All deaths reported in the country
# 2  Females  Total  Use of alcohol  All deaths reported in the country
# 3  Females  Total  Use of alcohol  All deaths reported in the country
# 4  Females  Total  Use of alcohol  All deaths reported in the country
#
#        country  2016   2017   2018   2019   2020   2021   2022   2023
# 0      Austria  87.0  104.0  123.0  104.0  108.0  143.0  135.0  144.0
# 1      Belgium  99.0  112.0   90.0   93.0  111.0   79.0  103.0    NaN
# 2     Bulgaria   1.0    3.0    3.0    3.0    6.0    9.0    1.0    NaN
# 3  Switzerland  52.0   48.0   63.0   44.0   58.0   42.0   59.0    NaN
# 4       Cyprus   NaN    0.0    2.0    1.0    1.0    1.0    0.0    NaN

# %%
df = df[df.resid=='All deaths reported in the country']
df = df.drop(columns=['resid'])
df = df.sort_values(by=['country', 'cause', 'age']).reset_index(drop=True)
df
# Out:
#           sex                  age           cause         country   2016  \
# 0     Females     65 years or over        COVID-19         Austria    0.0
# 1       Males     65 years or over        COVID-19         Austria    0.0
# 2       Total     65 years or over        COVID-19         Austria    0.0
# 3     Females  From 15 to 29 years        COVID-19         Austria    0.0
# 4       Males  From 15 to 29 years        COVID-19         Austria    0.0
# ...       ...                  ...             ...             ...    ...
# 3955    Males   Less than 15 years  Use of alcohol  United Kingdom    0.0
# 3956    Total   Less than 15 years  Use of alcohol  United Kingdom    0.0
# 3957  Females                Total  Use of alcohol  United Kingdom  251.0
# 3958    Males                Total  Use of alcohol  United Kingdom  610.0
# 3959    Total                Total  Use of alcohol  United Kingdom  861.0
#
#        2017   2018  2019    2020    2021    2022    2023
# 0       0.0    0.0   0.0  2973.0  3373.0  2960.0  1255.0
# 1       0.0    0.0   0.0  3146.0  3669.0  2979.0  1379.0
# 2       0.0    0.0   0.0  6119.0  7042.0  5939.0  2634.0
# 3       0.0    0.0   0.0     1.0     3.0     8.0     0.0
# 4       0.0    0.0   0.0     3.0    15.0     5.0     3.0
# ...     ...    ...   ...     ...     ...     ...     ...
# 3955    0.0    0.0   NaN     NaN     NaN     NaN     NaN
# 3956    0.0    0.0   NaN     NaN     NaN     NaN     NaN
# 3957  288.0  310.0   NaN     NaN     NaN     NaN     NaN
# 3958  665.0  683.0   NaN     NaN     NaN     NaN     NaN
# 3959  953.0  993.0   NaN     NaN     NaN     NaN     NaN
#
# [3960 rows x 12 columns]

# %%
df.to_csv("./clean/estat_hlth_cd_aro.csv", index=False)

# %%
mental_only = df[df['cause'] != 'COVID-19']
mental_only
# Out:
#           sex                  age            cause         country   2016  \
# 18    Females     65 years or over  Drug dependence         Austria    3.0
# 19      Males     65 years or over  Drug dependence         Austria    9.0
# 20      Total     65 years or over  Drug dependence         Austria   12.0
# 21    Females  From 15 to 29 years  Drug dependence         Austria    5.0
# 22      Males  From 15 to 29 years  Drug dependence         Austria   15.0
# ...       ...                  ...              ...             ...    ...
# 3955    Males   Less than 15 years   Use of alcohol  United Kingdom    0.0
# 3956    Total   Less than 15 years   Use of alcohol  United Kingdom    0.0
# 3957  Females                Total   Use of alcohol  United Kingdom  251.0
# 3958    Males                Total   Use of alcohol  United Kingdom  610.0
# 3959    Total                Total   Use of alcohol  United Kingdom  861.0
#
#        2017   2018  2019  2020  2021  2022  2023
# 18      6.0    4.0   7.0  10.0  13.0   6.0   9.0
# 19      3.0    6.0   7.0  10.0   8.0  10.0  15.0
# 20      9.0   10.0  14.0  20.0  21.0  16.0  24.0
# 21      1.0    3.0   5.0   6.0   3.0   2.0   3.0
# 22     10.0   19.0  17.0  10.0  15.0  10.0   9.0
# ...     ...    ...   ...   ...   ...   ...   ...
# 3955    0.0    0.0   NaN   NaN   NaN   NaN   NaN
# 3956    0.0    0.0   NaN   NaN   NaN   NaN   NaN
# 3957  288.0  310.0   NaN   NaN   NaN   NaN   NaN
# 3958  665.0  683.0   NaN   NaN   NaN   NaN   NaN
# 3959  953.0  993.0   NaN   NaN   NaN   NaN   NaN
#
# [3330 rows x 12 columns]

# %%
mental_only.to_csv("./clean/mental_grouped_only.csv", index=False)
