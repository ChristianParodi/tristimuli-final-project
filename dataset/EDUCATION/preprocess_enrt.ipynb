# %%
import pandas as pd
import numpy as np
import glob

# %%
df = pd.read_csv('estat_educ_uoe_enrt02.csv')
df.columns = df.columns.str.strip()
df = df.apply(lambda x: x.str.strip() if x.dtype == "object" else x)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16866 entries, 0 to 16865
# Data columns (total 13 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   freq     16866 non-null  object
#  1   unit     16866 non-null  object
#  2   age      16866 non-null  object
#  3   sex      16866 non-null  object
#  4   isced11  16866 non-null  object
#  5   geo      16866 non-null  object
#  6   2016     16866 non-null  object
#  7   2017     16866 non-null  object
#  8   2018     16866 non-null  object
#  9   2019     16866 non-null  object
#  10  2020     16866 non-null  object
#  11  2021     16866 non-null  object
#  12  2022     16866 non-null  object
# dtypes: object(13)
# memory usage: 1.7+ MB

# %%
path = '../ESTAT_CODELISTS/*.tsv'
files = glob.glob(path)

dataframes = {file.split('/')[-1].replace('.tsv', ''): pd.read_csv(
    file, sep='\t') for file in files}

# %%
for col in ["freq", "unit", "sex", "age", "isced11", "geo"]:
    curr_codelist = dataframes[f"ESTAT_{col.upper()}"]
    df[col] = df[col].map(curr_codelist.set_index('CODE')['Label'])

df.rename(columns={'geo': 'country'}, inplace=True)

df.head()
# Out:
#      freq    unit    age      sex                         isced11  \
# 0  Annual  Number  Total  Females  Short-cycle tertiary education
# 1  Annual  Number  Total  Females  Short-cycle tertiary education
# 2  Annual  Number  Total  Females  Short-cycle tertiary education
# 3  Annual  Number  Total  Females  Short-cycle tertiary education
# 4  Annual  Number  Total  Females  Short-cycle tertiary education
#
#                   country   2016   2017   2018   2019      2020   2021   2022
# 0                 Albania      :      :      :      :         :   2185   2561
# 1                 Austria  41271  40562  40188  39272     38738  39989  40489
# 2  Bosnia and Herzegovina      :      :    : z    : z       : z    : z     28
# 3                 Belgium  15351  14696  13850  13390  12400 bd  14159  14283
# 4                Bulgaria    : z    : z    : z    : z       : z    : z    : z

# %% [markdown]
# ## Replace ":" with NaN

# %%
df.replace(": z", np.nan, inplace=True)
df.replace(":", np.nan, inplace=True)

# %% [markdown]
# ## remove all the flags

# %%
year_cols = [col for col in df.columns if col.isdigit()]

for col in year_cols:
    df[col] = df[col].astype(str).str.extract(r'(\d+)').astype(float)

# %%
for col in df.columns:
    if not col.isdigit() and df[col].nunique() == 1:
        df.drop(columns=[col], inplace=True)

df.rename(columns={'isced11': 'level'}, inplace=True)

# %%
df.head()
# Out:
#      age      sex                           level                 country  \
# 0  Total  Females  Short-cycle tertiary education                 Albania
# 1  Total  Females  Short-cycle tertiary education                 Austria
# 2  Total  Females  Short-cycle tertiary education  Bosnia and Herzegovina
# 3  Total  Females  Short-cycle tertiary education                 Belgium
# 4  Total  Females  Short-cycle tertiary education                Bulgaria
#
#       2016     2017     2018     2019     2020     2021     2022
# 0      NaN      NaN      NaN      NaN      NaN   2185.0   2561.0
# 1  41271.0  40562.0  40188.0  39272.0  38738.0  39989.0  40489.0
# 2      NaN      NaN      NaN      NaN      NaN      NaN     28.0
# 3  15351.0  14696.0  13850.0  13390.0  12400.0  14159.0  14283.0
# 4      NaN      NaN      NaN      NaN      NaN      NaN      NaN

# %%
df.head()
# Out:
#      age      sex                           level                 country  \
# 0  Total  Females  Short-cycle tertiary education                 Albania
# 1  Total  Females  Short-cycle tertiary education                 Austria
# 2  Total  Females  Short-cycle tertiary education  Bosnia and Herzegovina
# 3  Total  Females  Short-cycle tertiary education                 Belgium
# 4  Total  Females  Short-cycle tertiary education                Bulgaria
#
#       2016     2017     2018     2019     2020     2021     2022
# 0      NaN      NaN      NaN      NaN      NaN   2185.0   2561.0
# 1  41271.0  40562.0  40188.0  39272.0  38738.0  39989.0  40489.0
# 2      NaN      NaN      NaN      NaN      NaN      NaN     28.0
# 3  15351.0  14696.0  13850.0  13390.0  12400.0  14159.0  14283.0
# 4      NaN      NaN      NaN      NaN      NaN      NaN      NaN

# %%
df['country'] = df["country"].replace('Türkiye', 'Turkey')

# %%
df = df.loc[df["country"] != "European Union - 28 countries (2013-2020)"]
df.loc[:, 'country'] = df["country"].replace(
    'European Union - 27 countries (from 2020)', 'European Union')

# %%
# Group by country and calculate the mean enrollments across all years for sex="Total"
df_totals = df[(df['sex'] == "Total") &
               (df['age'] == 'Total') &
               (df["level"] == 'Tertiary education (levels 5-8)')].groupby(
    'country')[year_cols].mean().reset_index()

# Compute the mean enrollment across all specified years
df_totals['enrollments'] = df_totals[year_cols].mean(axis=1)
df_totals = df_totals.sort_values('enrollments', ascending=False)

# Calculate thresholds using quantiles (33% and 66%)
low_threshold = df_totals['enrollments'].quantile(0.33)
high_threshold = df_totals['enrollments'].quantile(0.66)

# Create categories based on the mean enrollments
df_totals['enrollment_category'] = pd.cut(
    df_totals['enrollments'],
    bins=[-float('inf'), low_threshold, high_threshold, float('inf')],
    labels=['Low', 'Medium', 'High']
)

# Display results with categories
df_totals = df_totals[['country', 'enrollments', 'enrollment_category']].sort_values(
    'enrollments', ascending=False
).reset_index(drop=True)

# %%
# Define new thresholds
thresholds = [20000, 50000, 100000, 300000,
              500000, 1000000, 3000000, 8000000]

# Create categories with new thresholds
df_totals['enrollment_category'] = pd.cut(df_totals['enrollments'],
                                          bins=[-float('inf')] +
                                          thresholds + [float('inf')],
                                          labels=['Extremely Low', 'Very Low', 'Low', 'Medium Low', 'Medium', 'Medium High', 'High', 'Very High', 'Extremely High'])

# Display results with new categories
df_totals = df_totals[['country', 'enrollments', 'enrollment_category']].sort_values(
    'enrollments', ascending=False).reset_index(drop=True)

# %%
df_totals
# Out:
#                    country   enrollments enrollment_category
# 0           European Union  1.773803e+07      Extremely High
# 1                   Turkey  7.682506e+06           Very High
# 2                  Germany  3.221900e+06           Very High
# 3                   France  2.679739e+06                High
# 4           United Kingdom  2.473982e+06                High
# 5                    Spain  2.118623e+06                High
# 6                    Italy  1.965719e+06                High
# 7                   Poland  1.453973e+06                High
# 8              Netherlands  9.066737e+05         Medium High
# 9                   Greece  7.892173e+05         Medium High
# 10                 Romania  5.424600e+05         Medium High
# 11                 Belgium  5.257356e+05         Medium High
# 12                  Sweden  4.491297e+05              Medium
# 13                 Austria  4.306616e+05              Medium
# 14                Portugal  3.736924e+05              Medium
# 15                 Czechia  3.369516e+05              Medium
# 16             Switzerland  3.151951e+05              Medium
# 17                 Denmark  3.102901e+05              Medium
# 18                 Finland  2.999366e+05          Medium Low
# 19                  Norway  2.951853e+05          Medium Low
# 20                 Hungary  2.876180e+05          Medium Low
# 21                  Serbia  2.496690e+05          Medium Low
# 22                Bulgaria  2.374847e+05          Medium Low
# 23                 Ireland  2.343789e+05          Medium Low
# 24                 Croatia  1.628137e+05          Medium Low
# 25                Slovakia  1.468884e+05          Medium Low
# 26                 Albania  1.238385e+05          Medium Low
# 27               Lithuania  1.150116e+05          Medium Low
# 28  Bosnia and Herzegovina  8.579180e+04                 Low
# 29                  Latvia  8.064071e+04                 Low
# 30                Slovenia  7.914386e+04                 Low
# 31         North Macedonia  5.842971e+04                 Low
# 32                  Cyprus  4.895514e+04            Very Low
# 33                 Estonia  4.619614e+04            Very Low
# 34              Montenegro  2.364250e+04            Very Low
# 35                 Iceland  1.940386e+04       Extremely Low
# 36                   Malta  1.643257e+04       Extremely Low
# 37              Luxembourg  7.286000e+03       Extremely Low
# 38           Liechtenstein  8.844286e+02       Extremely Low

# %%
df_totals.to_json("clean/enrollmentQuantiles.json", orient = 'records')

# %%
print(f"{thresholds=}")
# Out:
# thresholds=[20000, 50000, 100000, 300000, 500000, 1000000, 3000000, 8000000]

# %%
# df.to_csv("./clean/estat_educ_uoe_enrt02.csv", index=False)
